# %%
import pandas
import faker

# %%
df=pandas.read_csv("/Users/yashagarwal/Darsh/hackathon/OPEN Hack/datasets_EasyEats/complete_menu_items_with_nutrients.csv")

# %%
'''columns = ['Proteins', 'Minerals', 'Vitamins', 'Carbohydrates', 'Fats', 'Fibers', 'Sugars']

for col in columns:
    df[col] = df[col].replace({'Low': 1, 'Medium': 2, 'High': 3})'''
# Out:
# "columns = ['Proteins', 'Minerals', 'Vitamins', 'Carbohydrates', 'Fats', 'Fibers', 'Sugars']\n\nfor col in columns:\n    df[col] = df[col].replace({'Low': 1, 'Medium': 2, 'High': 3})"

# %%
df
# Out:
#                        item_name Protiens Minerals Vitamins Carbohydrates  \
# 0     Outback Center-Cut Sirloin     High   Medium      Low        Medium
# 1     Outback Center-Cut Sirloin     High   Medium      Low        Medium
# 2            Bone-In Ribeye 18oz     High   Medium      Low           Low
# 3            Bone-In Ribeye 18oz     High   Medium      Low           Low
# 4      New York-Style Cheesecake   Medium      Low      Low          High
# ...                          ...      ...      ...      ...           ...
# 5748  Cinnabon Delights® 12 Pack      Low      Low      Low          High
# 5749  Cinnabon Delights® 12 Pack      Low      Low      Low          High
# 5750  Cinnabon Delights® 12 Pack      Low      Low      Low          High
# 5751  Cinnabon Delights® 12 Pack      Low      Low      Low          High
# 5752  Cinnabon Delights® 12 Pack      Low      Low      Low          High
#
#         Fats Fibers Sugars  Calories    Dish_type Primary_Flavour  \
# 0     Medium    Low    Low     500.0  main course          Savory
# 1     Medium    Low    Low     500.0  main course          Savory
# 2       High    Low    Low     850.0  main course          Savory
# 3       High    Low    Low     850.0  main course          Savory
# 4       High    Low   High     500.0      dessert           Sweet
# ...      ...    ...    ...       ...          ...             ...
# 5748  Medium    Low   High     930.0      dessert           Sweet
# 5749  Medium    Low   High     930.0      dessert           Sweet
# 5750  Medium    Low   High     930.0      dessert           Sweet
# 5751  Medium    Low   High     930.0      dessert           Sweet
# 5752  Medium    Low   High     930.0      dessert           Sweet
#
#      Secondary_Flavour                                        description  \
# 0                Umami  Center-cut for tenderness. Lean, hearty and fu...
# 1                Umami  Center-cut for tenderness. Lean, hearty and fu...
# 2                Umami  Bone-in and extra marbled for maximum tenderne...
# 3                Umami  Bone-in and extra marbled for maximum tenderne...
# 4               Creamy  Aussie-sized slice of premium New York-style c...
# ...                ...                                                ...
# 5748            Creamy  Warm donut holes filled with Cinnabon® signatu...
# 5749            Creamy  Warm donut holes filled with Cinnabon® signatu...
# 5750            Creamy  Warm donut holes filled with Cinnabon® signatu...
# 5751            Creamy  Warm donut holes filled with Cinnabon® signatu...
# 5752            Creamy  Warm donut holes filled with Cinnabon® signatu...
#
#                                     restaurant_name  score      price
# 0     Outback Steakhouse (9049 Vantage Point Drive)    4.5  21.98 USD
# 1     Outback Steakhouse (9049 Vantage Point Drive)    4.5  21.98 USD
# 2     Outback Steakhouse (9049 Vantage Point Drive)    4.5  31.33 USD
# 3     Outback Steakhouse (9049 Vantage Point Drive)    4.5  31.33 USD
# 4     Outback Steakhouse (9049 Vantage Point Drive)    4.5   9.88 USD
# ...                                             ...    ...        ...
# 5748                  Taco Bell (11829 Abrams Road)    4.4   7.19 USD
# 5749                  Taco Bell (11829 Abrams Road)    4.4   7.19 USD
# 5750                    Taco Bell (11702 Plano Rd.)    4.3   7.19 USD
# 5751                    Taco Bell (11702 Plano Rd.)    4.3   7.19 USD
# 5752                    Taco Bell (11702 Plano Rd.)    4.3   7.19 USD
#
# [5753 rows x 16 columns]

# %%
df2=pandas.DataFrame()
df2["Food Item"]=df["item_name"]

# %% [markdown]
# ## Calculating explicit Utility for our dishes with example of a weightloss diet

# %%
def calculate_explicit_utility_weightloss(proteins_rank, minerals_rank, vitamins_rank, carbohydrates_rank, fats_rank, fibers_rank, sugars_rank):
    # Define weights for each nutrient category
    weights = {'Proteins': 3, 'Minerals': 2, 'Vitamins': 2, 'Carbohydrates': 1, 'Fats': 1, 'Fibers': 3, 'Sugars': 1}
    
    # Define mapping of rankings to weights
    ranking_weights = {'Low': 1, 'Medium': 2, 'High': 3}

    calorie=400

    # Calculate scores for each nutrient category
    scores = {'Proteins': weights['Proteins']-ranking_weights[proteins_rank] >0,
              'Minerals': (ranking_weights[minerals_rank] - weights['Minerals']) if -ranking_weights[minerals_rank] + weights['Minerals'] > 0 else 1.2*(ranking_weights[minerals_rank] - weights['Minerals']),
              'Vitamins': (-ranking_weights[vitamins_rank] + weights['Vitamins']) if -ranking_weights[vitamins_rank] + weights['Vitamins'] > 0 else 0.8*(-ranking_weights[vitamins_rank] + weights['Vitamins']),
              'Carbohydrates': (-ranking_weights[carbohydrates_rank] + weights['Carbohydrates']) if -ranking_weights[carbohydrates_rank] + weights['Carbohydrates'] > 0 else (-ranking_weights[carbohydrates_rank] + weights['Carbohydrates'])**2,
              'Fats': (-ranking_weights[fats_rank] + weights['Fats']) if -ranking_weights[fats_rank] + weights['Fats'] > 0 else (-ranking_weights[fats_rank] + weights['Fats'])**2,
              'Fibers': (-ranking_weights[fibers_rank] + weights['Fibers']),
              'Sugars': (-ranking_weights[sugars_rank] + weights['Sugars']) if -ranking_weights[sugars_rank] + weights['Sugars'] > 0 else (-ranking_weights[sugars_rank] + weights['Sugars'])**2}
    # Calculate overall utility score
    utility_score = sum(scores.values())
    
    return utility_score

explicit_dietry_utility=[]

for i in range(0, len(df)):
    print(df.iloc[i]['Protiens'], df.iloc[i]['Minerals'], df.iloc[i]['Vitamins'], df.iloc[i]['Carbohydrates'], df.iloc[i]['Fats'], df.iloc[i]['Fibers'], df.iloc[i]['Sugars'])
    utility_score = calculate_explicit_utility_weightloss(df.iloc[i]['Protiens'], df.iloc[i]['Minerals'], df.iloc[i]['Vitamins'], df.iloc[i]['Carbohydrates'], df.iloc[i]['Fats'], df.iloc[i]['Fibers'], df.iloc[i]['Sugars'])
    print("Utility Score:", utility_score)
    explicit_dietry_utility.append(utility_score)
    print("\n")

df2['Explicit Dietry Utility'] = explicit_dietry_utility
# Out:
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Low Low Low High High Low Low
# Utility Score: 11
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Medium Low High Medium Low Low
# Utility Score: 9.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Medium High High Medium Low
# Utility Score: 9.0
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Medium High High Low Low
# Utility Score: 10.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Low Low Low Medium Medium Low
# Utility Score: 3
#
#
# High Medium Medium Low High Medium Low
# Utility Score: 5.0
#
#
# Medium High High Low Medium High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Low Medium High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Low Medium High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Low Medium High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Low Medium High Low
# Utility Score: 2.4000000000000004
#
#
# Medium Low High Medium High Medium Low
# Utility Score: 5.2
#
#
# Medium Low High Medium High Medium Low
# Utility Score: 5.2
#
#
# Medium Low High Medium High Medium Low
# Utility Score: 5.2
#
#
# Medium Low High Medium High Medium Low
# Utility Score: 5.2
#
#
# Medium Low High Medium High Medium Low
# Utility Score: 5.2
#
#
# Medium High High Medium High High Low
# Utility Score: 6.4
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Medium Low High High Medium Low
# Utility Score: 11.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# Medium Medium Low High High Medium Low
# Utility Score: 11.0
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# Medium Low Medium High High Low High
# Utility Score: 14.0
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# Medium Low Low High High Low High
# Utility Score: 15
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Low Medium Medium Low Medium Medium Low
# Utility Score: 3.0
#
#
# Low Medium Medium Low Medium Medium Low
# Utility Score: 3.0
#
#
# Low Medium Medium Low Medium Medium Low
# Utility Score: 3.0
#
#
# Low Medium Medium Low Medium Medium Low
# Utility Score: 3.0
#
#
# Low Medium Medium Low Medium Medium Low
# Utility Score: 3.0
#
#
# Medium Low Medium Low High Medium Low
# Utility Score: 5.0
#
#
# Low High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Medium Medium Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low Low High Low Low
# Utility Score: 7
#
#
# Medium Low Low Low High Low Low
# Utility Score: 7
#
#
# Medium Low Low Low High Low Low
# Utility Score: 7
#
#
# Medium Low Low Low High Low Low
# Utility Score: 7
#
#
# High Medium Medium Medium Low Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Medium Low Low Low
# Utility Score: 3.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Low Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Low Low High Medium Medium Low
# Utility Score: 7
#
#
# Medium High Medium High Low High Low
# Utility Score: 6.2
#
#
# Low Medium Medium High Low Medium Low
# Utility Score: 6.0
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Low Low Low High Medium Low High
# Utility Score: 12
#
#
# Medium Low Low High High Low Medium
# Utility Score: 12
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Medium High High Medium Low
# Utility Score: 9.0
#
#
# High Medium Medium High High Low Low
# Utility Score: 10.0
#
#
# High Medium Low Medium High Medium Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# Medium Medium Low High Medium High Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Medium High Low
# Utility Score: 7.0
#
#
# Medium High Medium High Low High Low
# Utility Score: 6.2
#
#
# Medium High Medium High Low High Low
# Utility Score: 6.2
#
#
# Low Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Low Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Low Medium High Medium Low Medium Low
# Utility Score: 2.2
#
#
# Low Medium High Low Low Medium Low
# Utility Score: 1.2
#
#
# Medium Low Low High High Medium Low
# Utility Score: 10
#
#
# Low Medium High Medium High Medium Low
# Utility Score: 6.2
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Low High Medium
# Utility Score: 6.0
#
#
# High Medium Low High Low High Medium
# Utility Score: 6.0
#
#
# High Medium Medium High Low High Low
# Utility Score: 4.0
#
#
# Medium Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# High Medium Low High Medium High Low
# Utility Score: 6.0
#
#
# High Medium Low High Medium High Low
# Utility Score: 6.0
#
#
# Low Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Low Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Low High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium High High Medium Low Low
# Utility Score: 6.2
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Medium High High Low Medium Low
# Utility Score: 5.2
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Low Medium Low Low Low Low
# Utility Score: 2.0
#
#
# Medium Low Medium Low Low Low Low
# Utility Score: 2.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Low Low Medium Low Low Medium
# Utility Score: 5
#
#
# Medium Low Low Medium Low Low Medium
# Utility Score: 5
#
#
# Medium Low Medium High Medium Low Low
# Utility Score: 7.0
#
#
# Medium Low Low High High Low Medium
# Utility Score: 12
#
#
# Medium Low High Low Low Medium Low
# Utility Score: 0.19999999999999996
#
#
# High Medium Medium Medium High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low Low Low Low Low
# Utility Score: 3
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# Medium Low Low Medium High Low Medium
# Utility Score: 9
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Low Low High Medium High Low
# Utility Score: 6
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Medium Medium High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium High Low Medium Medium Low
# Utility Score: 1.2
#
#
# High Medium High Low Low High Low
# Utility Score: -0.8
#
#
# High Medium High Low Low High Low
# Utility Score: -0.8
#
#
# High Medium Low Low Medium High Low
# Utility Score: 2.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Medium Low Low Low Low
# Utility Score: 2.0
#
#
# Low Medium Medium Low Medium High Low
# Utility Score: 2.0
#
#
# High Medium High Low Low Medium Low
# Utility Score: 0.19999999999999996
#
#
# Low Medium High Low Low High Medium
# Utility Score: 1.2
#
#
# Medium Medium High Low Low High Low
# Utility Score: 0.19999999999999996
#
#
# Medium Medium High Low Low High Low
# Utility Score: 0.19999999999999996
#
#
# Medium Low Medium Low Low Medium Low
# Utility Score: 1.0
#
#
# Medium Low Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# Medium Low Medium Low Low Medium Low
# Utility Score: 1.0
#
#
# Medium Low Medium Low Low Medium Low
# Utility Score: 1.0
#
#
# High Medium Medium Low Low Low Low
# Utility Score: 2.0
#
#
# Medium Low Medium Low High Low Low
# Utility Score: 6.0
#
#
# Medium High Low Low Low Low Low
# Utility Score: 5.2
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# Medium High Medium High Low Medium Low
# Utility Score: 7.2
#
#
# High Medium Medium Medium Low Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Medium Low Medium Low
# Utility Score: 2.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# Medium Low Medium Medium Low High Low
# Utility Score: 1.0
#
#
# Medium Low Medium Medium Low High Low
# Utility Score: 1.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium High Low Low Medium Low
# Utility Score: 0.19999999999999996
#
#
# High Medium Medium Medium Low Medium Low
# Utility Score: 2.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Medium Medium Medium Low Low
# Utility Score: 4.0
#
#
# Medium Medium High Low Low High Low
# Utility Score: 0.19999999999999996
#
#
# Medium Medium High Low Medium High Low
# Utility Score: 1.2
#
#
# Medium Medium High Low Medium High Low
# Utility Score: 1.2
#
#
# High Medium Medium Low Low Medium Low
# Utility Score: 1.0
#
#
# Low High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# High Medium Medium Low Medium Medium Low
# Utility Score: 2.0
#
#
# High Medium Medium Low Medium Medium Low
# Utility Score: 2.0
#
#
# High Medium Low Medium Low Medium Low
# Utility Score: 3.0
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Medium Medium High Low Medium Low
# Utility Score: 6.0
#
#
# Medium Low Low High Medium Medium Medium
# Utility Score: 8
#
#
# Medium High Medium High Low Medium Low
# Utility Score: 7.2
#
#
# Medium High Medium High Low Medium Low
# Utility Score: 7.2
#
#
# Medium Medium Low High Medium Low Low
# Utility Score: 9.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium High High High Low Medium Low
# Utility Score: 6.4
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# High Medium Medium High Low Medium Low
# Utility Score: 5.0
#
#
# Medium Medium High Low Medium Low Low
# Utility Score: 3.2
#
#
# Medium Medium High Low Medium Low Low
# Utility Score: 3.2
#
#
# Medium High Medium Medium High Low Low
# Utility Score: 9.2
#
#
# Medium High Medium Medium High Low Low
# Utility Score: 9.2
#
#
# Medium High Medium High Medium Low Low
# Utility Score: 9.2
#
#
# Medium High Medium High Medium Low Low
# Utility Score: 9.2
#
#
# Medium Medium High Low High Low Low
# Utility Score: 6.2
#
#
# Medium Medium High Low High Low Low
# Utility Score: 6.2
#
#
# Medium Low High Medium Medium Low High
# Utility Score: 7.2
#
#
# Medium Low High Medium Medium Low High
# Utility Score: 7.2
#
#
# Low High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# Medium Medium High Medium Medium Low Low
# Utility Score: 4.2
#
#
# Medium Low Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Low Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Medium High Medium Medium Low
# Utility Score: 6.0
#
#
# Medium Medium High High Medium Low Medium
# Utility Score: 8.2
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Low Low Low Low
# Utility Score: 2.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# Medium High Low Medium Low High Low
# Utility Score: 4.2
#
#
# High Medium Medium Low Low Medium Low
# Utility Score: 1.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Medium Low Low Low Low
# Utility Score: 2.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Low Medium High Medium Low Low
# Utility Score: 6.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Low Medium Medium Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low High Medium Low
# Utility Score: 6.0
#
#
# High Medium Low High Low Low Low
# Utility Score: 7.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium High Medium Low Low Low
# Utility Score: 2.2
#
#
# High Medium High Medium Low Low Low
# Utility Score: 2.2
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High High High Low Medium Low Low
# Utility Score: 3.4
#
#
# High High High Low Medium Low Low
# Utility Score: 3.4
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# Medium Low Medium Low High Low Low
# Utility Score: 6.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium High Low Medium Low Low
# Utility Score: 2.2
#
#
# High Medium High Low Medium Low Low
# Utility Score: 2.2
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Low Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Medium Low Low Low Low
# Utility Score: 2.0
#
#
# Medium Medium Low Low Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# Medium Low Medium High Low Medium Low
# Utility Score: 5.0
#
#
# Medium Low Medium High Low Medium Low
# Utility Score: 5.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Medium Low Medium Low
# Utility Score: 3.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# Medium Medium Low Medium High Low Low
# Utility Score: 9.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Medium
# Utility Score: 5.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# Medium Low Low Medium Low Low Medium
# Utility Score: 5
#
#
# Low Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Low High Medium Low High High Low
# Utility Score: 6.2
#
#
# Medium Low Low Medium High Low Low
# Utility Score: 8
#
#
# Low Low Medium Low Low Medium Low
# Utility Score: 1.0
#
#
# Medium Low Low Medium High Low Low
# Utility Score: 8
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Low Low Medium High Medium Low High
# Utility Score: 11.0
#
#
# Low Medium Low High Medium Low High
# Utility Score: 13.0
#
#
# Low Low Low High Medium Low High
# Utility Score: 12
#
#
# Low Low Low Medium Medium Low High
# Utility Score: 9
#
#
# High Medium Medium High Low Medium Low
# Utility Score: 5.0
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Medium Medium Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Low Low Low High Medium Low High
# Utility Score: 12
#
#
# Low Low Low High Medium Low High
# Utility Score: 12
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Low Medium Low High High Low Low
# Utility Score: 12.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Medium Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Medium Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low High
# Utility Score: 12.0
#
#
# High Medium Low High High Low Medium
# Utility Score: 12.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low High High Medium Medium
# Utility Score: 11.0
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Medium Medium High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low High High Medium Low
# Utility Score: 10.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Low Low High Low Medium
# Utility Score: 8.0
#
#
# High Medium Medium Medium Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low High High Medium Low
# Utility Score: 10
#
#
# Medium Low Medium Low High Medium Low
# Utility Score: 5.0
#
#
# High Medium High Low Medium High Low
# Utility Score: 0.19999999999999996
#
#
# High Medium Low Low High Medium Low
# Utility Score: 6.0
#
#
# Medium Medium High Medium Medium High Low
# Utility Score: 2.2
#
#
# Medium Medium High Medium Medium High Low
# Utility Score: 2.2
#
#
# Medium Medium High Medium Medium High Low
# Utility Score: 2.2
#
#
# Medium Medium High Medium Medium High Low
# Utility Score: 2.2
#
#
# Low Medium High High Medium Low High
# Utility Score: 11.2
#
#
# Low Medium High High Medium Low High
# Utility Score: 11.2
#
#
# Low Low Low High Medium Low High
# Utility Score: 12
#
#
# Medium High Medium Medium Low High Low
# Utility Score: 3.2
#
#
# Medium High Medium Medium Low High Low
# Utility Score: 3.2
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# Medium Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Medium Medium High Medium Low High Low
# Utility Score: 1.2
#
#
# Low Medium Medium High Low Medium Low
# Utility Score: 6.0
#
#
# Medium Medium Low High Medium High Low
# Utility Score: 7.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low High Medium High Low
# Utility Score: 6.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Medium Low High Low
# Utility Score: 2.4000000000000004
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Medium Low High Low Low
# Utility Score: 6.0
#
#
# High Medium Medium Low High Low Low
# Utility Score: 6.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# Medium Low Low High Medium Medium Low
# Utility Score: 7
#
#
# Medium Low Low High Medium Medium Low
# Utility Score: 7
#
#
# High Medium Low High Medium High Low
# Utility Score: 6.0
#
#
# Medium High High Low Low Medium Low
# Utility Score: 2.4000000000000004
#
#
# Medium High High Low Low Medium Low
# Utility Score: 2.4000000000000004
#
#
# High Medium Medium Low Low High Low
# Utility Score: 0.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Medium High High Low Low Low
# Utility Score: 6.2
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Medium High Low Low Medium Low
# Utility Score: 1.2
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Medium Low High High Low Low
# Utility Score: 12.0
#
#
# Medium Medium Low High High Low Low
# Utility Score: 12.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Medium Low
# Utility Score: 10.0
#
#
# Medium Medium Low High Medium Low Low
# Utility Score: 9.0
#
#
# Medium Medium Low High Medium Low Low
# Utility Score: 9.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Low Low Medium High Low Low
# Utility Score: 7
#
#
# High Low Low Medium High Low Low
# Utility Score: 7
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High High Medium Low Medium Low Low
# Utility Score: 4.2
#
#
# High Medium Medium Low Medium Low Low
# Utility Score: 3.0
#
#
# High High Medium Low Medium Low Low
# Utility Score: 4.2
#
#
# Medium High Low Low Low Low Low
# Utility Score: 5.2
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low Low Medium Low Low
# Utility Score: 4
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium High Low Medium Medium Low Low
# Utility Score: 7.2
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Low Low Medium High Low Low
# Utility Score: 7
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Medium Low High Low Low
# Utility Score: 6.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Medium Low Medium High Low Low
# Utility Score: 9.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low Low Medium Low Low
# Utility Score: 4
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low Low High Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Low Low High Medium Low Low
# Utility Score: 8
#
#
# High Medium Low High Medium Low Medium
# Utility Score: 9.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Low Medium High High Medium Low
# Utility Score: 8.0
#
#
# High Low Medium High High Medium Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# Medium Low Low High Medium Low High
# Utility Score: 12
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low Low Medium Low Low
# Utility Score: 4.0
#
#
# High Medium Low High Low Low Low
# Utility Score: 7.0
#
#
# High Medium Low High Low Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low Medium Low Low Low
# Utility Score: 4.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# High Medium Low High High Low Low
# Utility Score: 11.0
#
#
# Medium Medium Medium High Medium High Low
# Utility Score: 6.0
#
#
# Medium Medium Medium High Medium High Low
# Utility Score: 6.0
#
#
# Medium Medium Medium High Medium High Low
# Utility Score: 6.0
#
#
# Medium Medium Medium High Medium High Low
# Utility Score: 6.0
#
#
# High Medium Medium High Medium Medium Low
# Utility Score: 6.0
#
#
# High Medium Medium High Medium Medium Low
# Utility Score: 6.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Low Medium Low High Low Low High
# Utility Score: 12.0
#
#
# Low Medium Low High Low Low High
# Utility Score: 12.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Low Low High Medium Medium Low
# Utility Score: 7
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium Medium Low Low
# Utility Score: 5.0
#
#
# High Medium Low High Medium Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Medium Low
# Utility Score: 7.0
#
#
# Medium Medium Low High Low Low Low
# Utility Score: 8.0
#
#
# Medium Medium Low High Medium Medium Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# High Medium Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# High Medium Medium High High Low Low
# Utility Score: 10.0
#
#
# High Medium Low Medium High Low Low
# Utility Score: 8.0
#
#
# Medium Medium Low High High Low Low
# Utility Score: 12.0
#
#
# Medium Low Low High High Low Low
# Utility Score: 11
#
#
# Medium Low Medium High Medium Low Low
# Utility Score: 7.0
#
#
# High Medium Low High Medium Low Low
# Utility Score: 8.0
#
#
# Medium Low Low High High Medium Low
# Utility Score: 10
#
#
# High Moderate High High High Moderate Low
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 27
#      25 for i in range(0, len(df)):
#      26     print(df.iloc[i]['Protiens'], df.iloc[i]['Minerals'], df.iloc[i]['Vitamins'], df.iloc[i]['Carbohydrates'], df.iloc[i]['Fats'], df.iloc[i]['Fibers'], df.iloc[i]['Sugars'])
# ---> 27     utility_score = calculate_explicit_utility_weightloss(df.iloc[i]['Protiens'], df.iloc[i]['Minerals'], df.iloc[i]['Vitamins'], df.iloc[i]['Carbohydrates'], df.iloc[i]['Fats'], df.iloc[i]['Fibers'], df.iloc[i]['Sugars'])
#      28     print("Utility Score:", utility_score)
#      29     explicit_dietry_utility.append(utility_score)
#
# Cell In[9], line 12, in calculate_explicit_utility_weightloss(proteins_rank, minerals_rank, vitamins_rank, carbohydrates_rank, fats_rank, fibers_rank, sugars_rank)
#       8 calorie=400
#      10 # Calculate scores for each nutrient category
#      11 scores = {'Proteins': weights['Proteins']-ranking_weights[proteins_rank] >0,
# ---> 12           'Minerals': (ranking_weights[minerals_rank] - weights['Minerals']) if -ranking_weights[minerals_rank] + weights['Minerals'] > 0 else 1.2*(ranking_weights[minerals_rank] - weights['Minerals']),
#      13           'Vitamins': (-ranking_weights[vitamins_rank] + weights['Vitamins']) if -ranking_weights[vitamins_rank] + weights['Vitamins'] > 0 else 0.8*(-ranking_weights[vitamins_rank] + weights['Vitamins']),
#      14           'Carbohydrates': (-ranking_weights[carbohydrates_rank] + weights['Carbohydrates']) if -ranking_weights[carbohydrates_rank] + weights['Carbohydrates'] > 0 else (-ranking_weights[carbohydrates_rank] + weights['Carbohydrates'])**2,
#      15           'Fats': (-ranking_weights[fats_rank] + weights['Fats']) if -ranking_weights[fats_rank] + weights['Fats'] > 0 else (-ranking_weights[fats_rank] + weights['Fats'])**2,
#      16           'Fibers': (-ranking_weights[fibers_rank] + weights['Fibers']),
#      17           'Sugars': (-ranking_weights[sugars_rank] + weights['Sugars']) if -ranking_weights[sugars_rank] + weights['Sugars'] > 0 else (-ranking_weights[sugars_rank] + weights['Sugars'])**2}
#      18 # Calculate overall utility score
#      19 utility_score = sum(scores.values())
#
# KeyError: 'Moderate'

# %%
df2
# Out:
#                        Food Item  Explicit Dietry Utility
# 0     Outback Center-Cut Sirloin                      6.4
# 1                        Ribeye                       3.0
# 2            Bone-In Ribeye 18oz                      9.2
# 3      New York-Style Cheesecake                     12.2
# 4       Victoria's Filet® Mignon                     11.0
# ...                          ...                      ...
# 3783                 Black Beans                      5.0
# 3784        Black Beans and Rice                      6.2
# 3785             Cinnamon Twists                      6.0
# 3786   Cinnabon Delights® 2 Pack                     16.2
# 3787  Cinnabon Delights® 12 Pack                      6.2
#
# [3739 rows x 2 columns]

# %% [markdown]
# ## Using price and ratings as part of explict implicit utility

# %%
#explicit implicit utility
ratings_utility = []
print(len(df))
for i in range(0,len(df)):
    ratings_utility.append(5-df["Rating"].iloc[i])
df2["Ratings Utility"] = ratings_utility
price_utility=[]
for i in range(0,len(df)):
    price_utility.append(float(df["Price"].iloc[i][:-4])/10)
df2["Price Utility"] = price_utility
# Out:
# 3739

# %%
df2
# Out:
#                        Food Item  Explicit Dietry Utility  Ratings Utility  \
# 0     Outback Center-Cut Sirloin                      6.4              0.5
# 1                        Ribeye                       3.0              0.5
# 2            Bone-In Ribeye 18oz                      9.2              0.5
# 3      New York-Style Cheesecake                     12.2              0.5
# 4       Victoria's Filet® Mignon                     11.0              0.5
# ...                          ...                      ...              ...
# 3783                 Black Beans                      5.0              0.7
# 3784        Black Beans and Rice                      6.2              0.7
# 3785             Cinnamon Twists                      6.0              0.7
# 3786   Cinnabon Delights® 2 Pack                     16.2              0.7
# 3787  Cinnabon Delights® 12 Pack                      6.2              0.7
#
#       Price Utility
# 0             2.198
# 1             2.583
# 2             3.133
# 3             0.988
# 4             2.583
# ...             ...
# 3783          0.179
# 3784          0.179
# 3785          0.120
# 3786          0.179
# 3787          0.719
#
# [3739 rows x 4 columns]

# %%
#infusing flavour
flavor_profiles = [
    "Sweet",
    "Sour",
    "Salty",
    "Bitter",
    "Umami",
    "Spicy",
    "Herbal",
    "Earthy",
    "Nutty",
    "Fruity",
    "Floral",
    "Creamy",
    "Smoky",
    "Tangy"
]
fake=faker.Faker()
pf = [fake.random_element(flavor_profiles) for _ in range(len(df2))]
sf = [fake.random_element(flavor_profiles) for _ in range(len(df2))]

df2["Primary Flavour"] = pf
df2["Secondary Flavour"] = sf

# %%
df2
# Out:
#                        Food Item  Explicit Dietry Utility  Ratings Utility  \
# 0     Outback Center-Cut Sirloin                      6.4              0.5
# 1                        Ribeye                       3.0              0.5
# 2            Bone-In Ribeye 18oz                      9.2              0.5
# 3      New York-Style Cheesecake                     12.2              0.5
# 4       Victoria's Filet® Mignon                     11.0              0.5
# ...                          ...                      ...              ...
# 3783                 Black Beans                      5.0              0.7
# 3784        Black Beans and Rice                      6.2              0.7
# 3785             Cinnamon Twists                      6.0              0.7
# 3786   Cinnabon Delights® 2 Pack                     16.2              0.7
# 3787  Cinnabon Delights® 12 Pack                      6.2              0.7
#
#       Price Utility Primary Flavour Secondary Flavour
# 0             2.198          Bitter             Sweet
# 1             2.583            Sour            Fruity
# 2             3.133           Umami             Nutty
# 3             0.988           Tangy             Umami
# 4             2.583           Spicy            Creamy
# ...             ...             ...               ...
# 3783          0.179           Tangy            Herbal
# 3784          0.179           Sweet             Sweet
# 3785          0.120           Spicy             Nutty
# 3786          0.179           Tangy            Fruity
# 3787          0.719          Earthy             Sweet
#
# [3739 rows x 6 columns]

# %% [markdown]
# ### Sampling a set to hold placeholder for view item by users.

# %%
import random
ts = [round(random.uniform(1, 4), 1) for _ in range(len(df2))]

df2["Time spent"]=ts

tsma=df2["Time spent"].max()
tsmi=df2["Time spent"].min()
print()
tsu=[]
for i in range(0,len(df2)):
    tsu.append((round((df2["Time spent"].iloc[i]-tsmi)/(tsma-tsmi),2)))
df2["Time Spent Utility"]=tsu

# %%
sampled_df = df2.sample(n=50)
sampled_df
# Out:
#                                               Food Item  \
# 1264                                       Citti Deluxe
# 3643                   Ben & Jerry's Cherry Garcia Pint
# 756                                             Supreme
# 298                                              3 Meat
# 2681                       Steam Tofu and Mix Vegetable
# 2038         Sunjoy® (1/2 Sweet Tea, 1/2 Diet Lemonade)
# 176                                         Wonton Soup
# 2986            Grilled Sourdough Swiss Breakfast Combo
# 3725                             Spicy Potato Soft Taco
# 228                                       Skillman Roll
# 3541                7-Select Chocolate Cupcakes 2 Count
# 2146     Pearl Milling Company Pancake Mix Complete 1lb
# 2254                     Zyrtec Allergy Tablets 3 Count
# 1507                                            Hot Dog
# 1154                                        Spicy Hunan
# 3264                                 Steak &amp; Cheese
# 417                      One Piece Chicken Fried Basket
# 2437         Accu-Chek FastClix Lancing Device - 1.0 ea
# 1365                                    Medium Beverage
# 3293    Bacon, Egg &amp; Cheese 6 Inch with Regular Egg
# 1072                       Double Chicken Avocado Salad
# 144                                         Pad Kee Mow
# 3506                     OREO Frozen Dairy Dessert 14oz
# 3405                               Soft Taco Party Pack
# 164                                    Fish Cake (5pcs)
# 2594  Trojan Ultra Ribbed Premium Lubricated Condoms...
# 2355              Scotch 8" Precision Scissors - 1.0 EA
# 1453                                         Rice Bowls
# 1278                         Crispy Chicken Bacon Salad
# 1160                                          Red Curry
# 2239                      Ben & Jerry's Half Baked Pint
# 2084                                 8oz Barbeque Sauce
# 120                                           Shiro Wat
# 856                                  Chicken Parmigiana
# 37                            Perfectly Grilled Salmon
# 2253                         Dramamine Tablets 12 Count
# 1641                       CYO Pizza &amp; Pepsi Bundle
# 349                                       Kuanta Firfir
# 2569         WeVeel Silly Streamers Assortment - 3.0 oz
# 818                  Breast, Leg, Thigh and Wings Combo
# 3022                              Simply Orange Juice®
# 3271                              Baja Steak &amp; Jack
# 3700                                         Meal for 4
# 704                                     Tzatziki Spread
# 2399  Gerber Baby Food Banana Apple Pear - 4.0 oz x ...
# 3146                                          Cornbread
# 2753                             Sweet and Sour Shrimp
# 700                                Large Village Salad
# 1337                                Famous Bowl Fill Up
# 2467                 Walgreens Toning Shampoo - 16.0 oz
#
#       Explicit Dietry Utility  Ratings Utility  Price Utility Primary Flavour  \
# 1264                      1.0              0.5          1.199            Sour
# 3643                      3.2              0.2          0.729           Salty
# 756                       2.0              0.9          0.000          Herbal
# 298                       5.2              0.6          2.369          Herbal
# 2681                      1.2              0.6          1.435           Tangy
# 2038                      3.2              0.3          0.299           Smoky
# 176                      10.2              0.2          1.200          Fruity
# 2986                     10.2              0.9          0.774           Umami
# 3725                      7.0              0.7          0.120           Tangy
# 228                       6.0              0.2          1.650          Floral
# 3541                     11.0              0.2          0.199          Creamy
# 2146                      3.2              0.4          0.339           Salty
# 2254                      3.0              0.4          0.669          Creamy
# 1507                     12.0              0.3          0.200           Spicy
# 1154                      8.0              0.2          1.295            Sour
# 3264                      9.2              0.1          1.075          Earthy
# 417                       9.2              0.9          0.149          Herbal
# 2437                      1.0              0.3          1.731           Umami
# 1365                     11.0              0.5          0.287           Tangy
# 3293                      7.2              0.1          0.775           Spicy
# 1072                      2.0              0.4          0.879           Tangy
# 144                       9.0              0.2          1.250          Herbal
# 3506                      7.0              0.2          0.479          Creamy
# 3405                      6.0              0.6          2.039            Sour
# 164                       5.2              0.2          0.795          Creamy
# 2594                      8.0              0.3          3.148           Sweet
# 2355                      3.2              0.3          0.765           Umami
# 1453                      4.0              0.9          0.889          Fruity
# 1278                      6.0              0.5          0.799          Fruity
# 1160                      6.2              0.2          1.395          Fruity
# 2239                     13.0              0.4          0.729          Creamy
# 2084                      5.2              0.3          0.325          Creamy
# 120                       3.2              0.6          1.300           Spicy
# 856                       6.0              0.0          0.899          Creamy
# 37                        4.2              0.5          2.308          Earthy
# 2253                      4.2              0.4          0.859           Sweet
# 1641                      8.2              0.8          0.000           Sweet
# 349                      -0.8              0.2          1.500            Sour
# 2569                      9.0              0.3          0.418          Floral
# 818                       8.2              0.3          1.399          Creamy
# 3022                     15.0              0.9          0.311          Fruity
# 3271                      5.2              0.1          1.100           Tangy
# 3700                     12.0              0.7          2.500           Nutty
# 704                       8.0              0.2          0.829          Earthy
# 2399                      4.0              0.3          0.240            Sour
# 3146                      5.2              0.3          0.149          Fruity
# 2753                      5.2              0.6          1.710           Smoky
# 700                       4.0              0.2          1.000          Fruity
# 1337                      5.2              0.5          0.755           Nutty
# 2467                     12.4              0.3          1.048          Bitter
#
#      Secondary Flavour  Time spent  Time Spent Utility
# 1264            Herbal         1.2                0.07
# 3643            Earthy         2.1                0.37
# 756              Tangy         1.0                0.00
# 298              Nutty         1.5                0.17
# 2681              Sour         3.4                0.80
# 2038            Earthy         3.5                0.83
# 176             Earthy         1.4                0.13
# 2986            Earthy         2.4                0.47
# 3725            Floral         3.8                0.93
# 228              Smoky         1.2                0.07
# 3541             Smoky         1.1                0.03
# 2146             Smoky         3.2                0.73
# 2254             Smoky         3.1                0.70
# 1507            Bitter         3.3                0.77
# 1154            Fruity         1.6                0.20
# 3264             Smoky         3.5                0.83
# 417              Umami         1.6                0.20
# 2437             Salty         2.0                0.33
# 1365            Herbal         3.5                0.83
# 3293            Herbal         3.3                0.77
# 1072            Floral         3.0                0.67
# 144              Nutty         2.5                0.50
# 3506             Umami         3.2                0.73
# 3405             Spicy         1.2                0.07
# 164               Sour         1.7                0.23
# 2594             Sweet         2.0                0.33
# 2355            Bitter         2.9                0.63
# 1453              Sour         3.9                0.97
# 1278             Salty         2.6                0.53
# 1160             Nutty         2.3                0.43
# 2239            Fruity         3.0                0.67
# 2084            Bitter         2.7                0.57
# 120              Salty         2.6                0.53
# 856              Smoky         2.2                0.40
# 37               Spicy         1.1                0.03
# 2253             Salty         3.3                0.77
# 1641            Herbal         2.7                0.57
# 349             Fruity         3.7                0.90
# 2569            Fruity         3.9                0.97
# 818              Nutty         3.4                0.80
# 3022            Herbal         1.4                0.13
# 3271              Sour         1.5                0.17
# 3700              Sour         3.8                0.93
# 704             Floral         1.4                0.13
# 2399            Fruity         1.3                0.10
# 3146             Nutty         3.3                0.77
# 2753             Spicy         3.5                0.83
# 700             Creamy         3.5                0.83
# 1337            Herbal         2.2                0.40
# 2467             Umami         3.1                0.70

# %%
# user viewed items
freq_list=sampled_df["Primary Flavour"].value_counts()
freq_list.to_dict()
# Out:
# {'Creamy': 8,
#  'Fruity': 7,
#  'Sour': 5,
#  'Tangy': 5,
#  'Herbal': 4,
#  'Umami': 3,
#  'Spicy': 3,
#  'Earthy': 3,
#  'Sweet': 3,
#  'Salty': 2,
#  'Smoky': 2,
#  'Floral': 2,
#  'Nutty': 2,
#  'Bitter': 1}

# %% [markdown]
# ## IU- Implicit Utility calculation from the first implicit MAU (Multiple attribute utility)

# %%
#implicit utility of primary flavour
freq_utility={}
for k in freq_list.keys():
    freq_utility[k]=round((freq_list[k]-min(freq_list.values))/(max(freq_list.values)-min(freq_list.values)),2)
freq_utility
# Out:
# {'Creamy': 1.0,
#  'Fruity': 0.86,
#  'Sour': 0.57,
#  'Tangy': 0.57,
#  'Herbal': 0.43,
#  'Umami': 0.29,
#  'Spicy': 0.29,
#  'Earthy': 0.29,
#  'Sweet': 0.29,
#  'Salty': 0.14,
#  'Smoky': 0.14,
#  'Floral': 0.14,
#  'Nutty': 0.14,
#  'Bitter': 0.0}

# %%
freq_list2=sampled_df["Secondary Flavour"].value_counts()
freq_list2.to_dict()
# Out:
# {'Herbal': 6,
#  'Smoky': 6,
#  'Nutty': 5,
#  'Sour': 5,
#  'Fruity': 5,
#  'Earthy': 4,
#  'Salty': 4,
#  'Floral': 3,
#  'Bitter': 3,
#  'Umami': 3,
#  'Spicy': 3,
#  'Tangy': 1,
#  'Sweet': 1,
#  'Creamy': 1}

# %%
freq_utility2={}
for k in freq_list2.keys():
    freq_utility2[k]=round((freq_list2[k]-min(freq_list2.values))/(max(freq_list2.values)-min(freq_list2.values)),2)
freq_utility2
# Out:
# {'Herbal': 1.0,
#  'Smoky': 1.0,
#  'Nutty': 0.8,
#  'Sour': 0.8,
#  'Fruity': 0.8,
#  'Earthy': 0.6,
#  'Salty': 0.6,
#  'Floral': 0.4,
#  'Bitter': 0.4,
#  'Umami': 0.4,
#  'Spicy': 0.4,
#  'Tangy': 0.0,
#  'Sweet': 0.0,
#  'Creamy': 0.0}

# %%
iu1=[]
iu2=[]
for i in range(0,len(df2)):
    if df2["Primary Flavour"].iloc[i] in freq_utility.keys():
        iu1.append(freq_utility[df2["Primary Flavour"].iloc[i]])
    else:
        iu1.append(0)
    if df2["Secondary Flavour"].iloc[i] in freq_utility2.keys():
        iu2.append(freq_utility2[df2["Secondary Flavour"].iloc[i]])
    else:
        iu2.append(0)
df2["Implicit Utility 1"]=iu1
df2["Implicit Utility 2"]=iu2
df2
# Out:
#                        Food Item  Explicit Dietry Utility  Ratings Utility  \
# 0     Outback Center-Cut Sirloin                      6.4              0.5
# 1                        Ribeye                       3.0              0.5
# 2            Bone-In Ribeye 18oz                      9.2              0.5
# 3      New York-Style Cheesecake                     12.2              0.5
# 4       Victoria's Filet® Mignon                     11.0              0.5
# ...                          ...                      ...              ...
# 3783                 Black Beans                      5.0              0.7
# 3784        Black Beans and Rice                      6.2              0.7
# 3785             Cinnamon Twists                      6.0              0.7
# 3786   Cinnabon Delights® 2 Pack                     16.2              0.7
# 3787  Cinnabon Delights® 12 Pack                      6.2              0.7
#
#       Price Utility Primary Flavour Secondary Flavour  Time spent  \
# 0             2.198          Bitter             Sweet         2.2
# 1             2.583            Sour            Fruity         1.6
# 2             3.133           Umami             Nutty         4.0
# 3             0.988           Tangy             Umami         2.6
# 4             2.583           Spicy            Creamy         3.0
# ...             ...             ...               ...         ...
# 3783          0.179           Tangy            Herbal         3.0
# 3784          0.179           Sweet             Sweet         3.9
# 3785          0.120           Spicy             Nutty         3.1
# 3786          0.179           Tangy            Fruity         3.8
# 3787          0.719          Earthy             Sweet         3.1
#
#       Time Spent Utility  Implicit Utility 1  Implicit Utility 2
# 0                   0.40                0.00                 0.0
# 1                   0.20                0.57                 0.8
# 2                   1.00                0.29                 0.8
# 3                   0.53                0.57                 0.4
# 4                   0.67                0.29                 0.0
# ...                  ...                 ...                 ...
# 3783                0.67                0.57                 1.0
# 3784                0.97                0.29                 0.0
# 3785                0.70                0.29                 0.8
# 3786                0.93                0.57                 0.8
# 3787                0.70                0.29                 0.0
#
# [3739 rows x 10 columns]

# %%
df2
# Out:
#                        Food Item  Explicit Dietry Utility  Ratings Utility  \
# 0     Outback Center-Cut Sirloin                      6.4              0.5
# 1                        Ribeye                       3.0              0.5
# 2            Bone-In Ribeye 18oz                      9.2              0.5
# 3      New York-Style Cheesecake                     12.2              0.5
# 4       Victoria's Filet® Mignon                     11.0              0.5
# ...                          ...                      ...              ...
# 3783                 Black Beans                      5.0              0.7
# 3784        Black Beans and Rice                      6.2              0.7
# 3785             Cinnamon Twists                      6.0              0.7
# 3786   Cinnabon Delights® 2 Pack                     16.2              0.7
# 3787  Cinnabon Delights® 12 Pack                      6.2              0.7
#
#       Price Utility Primary Flavour Secondary Flavour  Time spent  \
# 0             2.198          Bitter             Sweet         2.2
# 1             2.583            Sour            Fruity         1.6
# 2             3.133           Umami             Nutty         4.0
# 3             0.988           Tangy             Umami         2.6
# 4             2.583           Spicy            Creamy         3.0
# ...             ...             ...               ...         ...
# 3783          0.179           Tangy            Herbal         3.0
# 3784          0.179           Sweet             Sweet         3.9
# 3785          0.120           Spicy             Nutty         3.1
# 3786          0.179           Tangy            Fruity         3.8
# 3787          0.719          Earthy             Sweet         3.1
#
#       Time Spent Utility  Implicit Utility 1  Implicit Utility 2
# 0                   0.40                0.00                 0.0
# 1                   0.20                0.57                 0.8
# 2                   1.00                0.29                 0.8
# 3                   0.53                0.57                 0.4
# 4                   0.67                0.29                 0.0
# ...                  ...                 ...                 ...
# 3783                0.67                0.57                 1.0
# 3784                0.97                0.29                 0.0
# 3785                0.70                0.29                 0.8
# 3786                0.93                0.57                 0.8
# 3787                0.70                0.29                 0.0
#
# [3739 rows x 10 columns]

# %%
sampled_df
# Out:
#                                               Food Item  \
# 1264                                       Citti Deluxe
# 3643                   Ben & Jerry's Cherry Garcia Pint
# 756                                             Supreme
# 298                                              3 Meat
# 2681                       Steam Tofu and Mix Vegetable
# 2038         Sunjoy® (1/2 Sweet Tea, 1/2 Diet Lemonade)
# 176                                         Wonton Soup
# 2986            Grilled Sourdough Swiss Breakfast Combo
# 3725                             Spicy Potato Soft Taco
# 228                                       Skillman Roll
# 3541                7-Select Chocolate Cupcakes 2 Count
# 2146     Pearl Milling Company Pancake Mix Complete 1lb
# 2254                     Zyrtec Allergy Tablets 3 Count
# 1507                                            Hot Dog
# 1154                                        Spicy Hunan
# 3264                                 Steak &amp; Cheese
# 417                      One Piece Chicken Fried Basket
# 2437         Accu-Chek FastClix Lancing Device - 1.0 ea
# 1365                                    Medium Beverage
# 3293    Bacon, Egg &amp; Cheese 6 Inch with Regular Egg
# 1072                       Double Chicken Avocado Salad
# 144                                         Pad Kee Mow
# 3506                     OREO Frozen Dairy Dessert 14oz
# 3405                               Soft Taco Party Pack
# 164                                    Fish Cake (5pcs)
# 2594  Trojan Ultra Ribbed Premium Lubricated Condoms...
# 2355              Scotch 8" Precision Scissors - 1.0 EA
# 1453                                         Rice Bowls
# 1278                         Crispy Chicken Bacon Salad
# 1160                                          Red Curry
# 2239                      Ben & Jerry's Half Baked Pint
# 2084                                 8oz Barbeque Sauce
# 120                                           Shiro Wat
# 856                                  Chicken Parmigiana
# 37                            Perfectly Grilled Salmon
# 2253                         Dramamine Tablets 12 Count
# 1641                       CYO Pizza &amp; Pepsi Bundle
# 349                                       Kuanta Firfir
# 2569         WeVeel Silly Streamers Assortment - 3.0 oz
# 818                  Breast, Leg, Thigh and Wings Combo
# 3022                              Simply Orange Juice®
# 3271                              Baja Steak &amp; Jack
# 3700                                         Meal for 4
# 704                                     Tzatziki Spread
# 2399  Gerber Baby Food Banana Apple Pear - 4.0 oz x ...
# 3146                                          Cornbread
# 2753                             Sweet and Sour Shrimp
# 700                                Large Village Salad
# 1337                                Famous Bowl Fill Up
# 2467                 Walgreens Toning Shampoo - 16.0 oz
#
#       Explicit Dietry Utility  Ratings Utility  Price Utility Primary Flavour  \
# 1264                      1.0              0.5          1.199            Sour
# 3643                      3.2              0.2          0.729           Salty
# 756                       2.0              0.9          0.000          Herbal
# 298                       5.2              0.6          2.369          Herbal
# 2681                      1.2              0.6          1.435           Tangy
# 2038                      3.2              0.3          0.299           Smoky
# 176                      10.2              0.2          1.200          Fruity
# 2986                     10.2              0.9          0.774           Umami
# 3725                      7.0              0.7          0.120           Tangy
# 228                       6.0              0.2          1.650          Floral
# 3541                     11.0              0.2          0.199          Creamy
# 2146                      3.2              0.4          0.339           Salty
# 2254                      3.0              0.4          0.669          Creamy
# 1507                     12.0              0.3          0.200           Spicy
# 1154                      8.0              0.2          1.295            Sour
# 3264                      9.2              0.1          1.075          Earthy
# 417                       9.2              0.9          0.149          Herbal
# 2437                      1.0              0.3          1.731           Umami
# 1365                     11.0              0.5          0.287           Tangy
# 3293                      7.2              0.1          0.775           Spicy
# 1072                      2.0              0.4          0.879           Tangy
# 144                       9.0              0.2          1.250          Herbal
# 3506                      7.0              0.2          0.479          Creamy
# 3405                      6.0              0.6          2.039            Sour
# 164                       5.2              0.2          0.795          Creamy
# 2594                      8.0              0.3          3.148           Sweet
# 2355                      3.2              0.3          0.765           Umami
# 1453                      4.0              0.9          0.889          Fruity
# 1278                      6.0              0.5          0.799          Fruity
# 1160                      6.2              0.2          1.395          Fruity
# 2239                     13.0              0.4          0.729          Creamy
# 2084                      5.2              0.3          0.325          Creamy
# 120                       3.2              0.6          1.300           Spicy
# 856                       6.0              0.0          0.899          Creamy
# 37                        4.2              0.5          2.308          Earthy
# 2253                      4.2              0.4          0.859           Sweet
# 1641                      8.2              0.8          0.000           Sweet
# 349                      -0.8              0.2          1.500            Sour
# 2569                      9.0              0.3          0.418          Floral
# 818                       8.2              0.3          1.399          Creamy
# 3022                     15.0              0.9          0.311          Fruity
# 3271                      5.2              0.1          1.100           Tangy
# 3700                     12.0              0.7          2.500           Nutty
# 704                       8.0              0.2          0.829          Earthy
# 2399                      4.0              0.3          0.240            Sour
# 3146                      5.2              0.3          0.149          Fruity
# 2753                      5.2              0.6          1.710           Smoky
# 700                       4.0              0.2          1.000          Fruity
# 1337                      5.2              0.5          0.755           Nutty
# 2467                     12.4              0.3          1.048          Bitter
#
#      Secondary Flavour  Time spent  Time Spent Utility
# 1264            Herbal         1.2                0.07
# 3643            Earthy         2.1                0.37
# 756              Tangy         1.0                0.00
# 298              Nutty         1.5                0.17
# 2681              Sour         3.4                0.80
# 2038            Earthy         3.5                0.83
# 176             Earthy         1.4                0.13
# 2986            Earthy         2.4                0.47
# 3725            Floral         3.8                0.93
# 228              Smoky         1.2                0.07
# 3541             Smoky         1.1                0.03
# 2146             Smoky         3.2                0.73
# 2254             Smoky         3.1                0.70
# 1507            Bitter         3.3                0.77
# 1154            Fruity         1.6                0.20
# 3264             Smoky         3.5                0.83
# 417              Umami         1.6                0.20
# 2437             Salty         2.0                0.33
# 1365            Herbal         3.5                0.83
# 3293            Herbal         3.3                0.77
# 1072            Floral         3.0                0.67
# 144              Nutty         2.5                0.50
# 3506             Umami         3.2                0.73
# 3405             Spicy         1.2                0.07
# 164               Sour         1.7                0.23
# 2594             Sweet         2.0                0.33
# 2355            Bitter         2.9                0.63
# 1453              Sour         3.9                0.97
# 1278             Salty         2.6                0.53
# 1160             Nutty         2.3                0.43
# 2239            Fruity         3.0                0.67
# 2084            Bitter         2.7                0.57
# 120              Salty         2.6                0.53
# 856              Smoky         2.2                0.40
# 37               Spicy         1.1                0.03
# 2253             Salty         3.3                0.77
# 1641            Herbal         2.7                0.57
# 349             Fruity         3.7                0.90
# 2569            Fruity         3.9                0.97
# 818              Nutty         3.4                0.80
# 3022            Herbal         1.4                0.13
# 3271              Sour         1.5                0.17
# 3700              Sour         3.8                0.93
# 704             Floral         1.4                0.13
# 2399            Fruity         1.3                0.10
# 3146             Nutty         3.3                0.77
# 2753             Spicy         3.5                0.83
# 700             Creamy         3.5                0.83
# 1337            Herbal         2.2                0.40
# 2467             Umami         3.1                0.70

# %% [markdown]
# ## Non linear optitimization of Implicity Utility (Flavour)

# %%
import numpy as np
from scipy.optimize import minimize
def objective(weights):
    fs = 0
    for i in range(len(df2)):
        s = 0
        for j in range(2):
            if j == 0:
                s += (df2["Time Spent Utility"].iloc[i] - df2["Implicit Utility 1"].iloc[i] * weights[j]) ** 2
            elif j == 1:
                s += (df2["Time Spent Utility"].iloc[i] - df2["Implicit Utility 2"].iloc[i] * weights[j]) ** 2
        fs += s
    return fs

# %%
def constraint(weights):
    return 1 - np.sum(weights)

# %%
w0=[0.5,0.5]
objective(w0)
# Out:
# 1459.7653500000006

# %% [markdown]
# ### Using Sequentential Least square Programming (SLSQP) to solve the problem

# %%
bound=(0,1)
bnd=[bound,bound]
con={"type":"eq","fun":constraint}
sol=minimize(objective,w0,method="SLSQP",bounds=bnd,constraints=con)
weights=sol.x.tolist()

# %% [markdown]
# ## Calculating final utility for the dishes

# %%
df2
# Out:
#                        Food Item  Explicit Dietry Utility  Ratings Utility  \
# 0     Outback Center-Cut Sirloin                      6.4              0.5
# 1                        Ribeye                       3.0              0.5
# 2            Bone-In Ribeye 18oz                      9.2              0.5
# 3      New York-Style Cheesecake                     12.2              0.5
# 4       Victoria's Filet® Mignon                     11.0              0.5
# ...                          ...                      ...              ...
# 3783                 Black Beans                      5.0              0.7
# 3784        Black Beans and Rice                      6.2              0.7
# 3785             Cinnamon Twists                      6.0              0.7
# 3786   Cinnabon Delights® 2 Pack                     16.2              0.7
# 3787  Cinnabon Delights® 12 Pack                      6.2              0.7
#
#       Price Utility Primary Flavour Secondary Flavour  Time spent  \
# 0             2.198          Bitter             Sweet         2.2
# 1             2.583            Sour            Fruity         1.6
# 2             3.133           Umami             Nutty         4.0
# 3             0.988           Tangy             Umami         2.6
# 4             2.583           Spicy            Creamy         3.0
# ...             ...             ...               ...         ...
# 3783          0.179           Tangy            Herbal         3.0
# 3784          0.179           Sweet             Sweet         3.9
# 3785          0.120           Spicy             Nutty         3.1
# 3786          0.179           Tangy            Fruity         3.8
# 3787          0.719          Earthy             Sweet         3.1
#
#       Time Spent Utility  Implicit Utility 1  Implicit Utility 2
# 0                   0.40                0.00                 0.0
# 1                   0.20                0.57                 0.8
# 2                   1.00                0.29                 0.8
# 3                   0.53                0.57                 0.4
# 4                   0.67                0.29                 0.0
# ...                  ...                 ...                 ...
# 3783                0.67                0.57                 1.0
# 3784                0.97                0.29                 0.0
# 3785                0.70                0.29                 0.8
# 3786                0.93                0.57                 0.8
# 3787                0.70                0.29                 0.0
#
# [3739 rows x 10 columns]

# %%
df2["Final Implicit utility"]=1-(df2["Implicit Utility 1"]*weights[0]+df2["Implicit Utility 2"]*weights[1])
df2
# Out:
#                        Food Item  Explicit Dietry Utility  Ratings Utility  \
# 0     Outback Center-Cut Sirloin                      6.4              0.5
# 1                        Ribeye                       3.0              0.5
# 2            Bone-In Ribeye 18oz                      9.2              0.5
# 3      New York-Style Cheesecake                     12.2              0.5
# 4       Victoria's Filet® Mignon                     11.0              0.5
# ...                          ...                      ...              ...
# 3783                 Black Beans                      5.0              0.7
# 3784        Black Beans and Rice                      6.2              0.7
# 3785             Cinnamon Twists                      6.0              0.7
# 3786   Cinnabon Delights® 2 Pack                     16.2              0.7
# 3787  Cinnabon Delights® 12 Pack                      6.2              0.7
#
#       Price Utility Primary Flavour Secondary Flavour  Time spent  \
# 0             2.198          Bitter             Sweet         2.2
# 1             2.583            Sour            Fruity         1.6
# 2             3.133           Umami             Nutty         4.0
# 3             0.988           Tangy             Umami         2.6
# 4             2.583           Spicy            Creamy         3.0
# ...             ...             ...               ...         ...
# 3783          0.179           Tangy            Herbal         3.0
# 3784          0.179           Sweet             Sweet         3.9
# 3785          0.120           Spicy             Nutty         3.1
# 3786          0.179           Tangy            Fruity         3.8
# 3787          0.719          Earthy             Sweet         3.1
#
#       Time Spent Utility  Implicit Utility 1  Implicit Utility 2  \
# 0                   0.40                0.00                 0.0
# 1                   0.20                0.57                 0.8
# 2                   1.00                0.29                 0.8
# 3                   0.53                0.57                 0.4
# 4                   0.67                0.29                 0.0
# ...                  ...                 ...                 ...
# 3783                0.67                0.57                 1.0
# 3784                0.97                0.29                 0.0
# 3785                0.70                0.29                 0.8
# 3786                0.93                0.57                 0.8
# 3787                0.70                0.29                 0.0
#
#       Final Implicit utility
# 0                   1.000000
# 1                   0.318006
# 2                   0.461666
# 3                   0.512778
# 4                   0.851210
# ...                      ...
# 3783                0.220620
# 3784                0.851210
# 3785                0.461666
# 3786                0.318006
# 3787                0.851210
#
# [3739 rows x 11 columns]

# %%
df2["Final Utility"]=round(df2["Explicit Dietry Utility"]/8)+df2["Ratings Utility"]+df2["Price Utility"]+df2["Final Implicit utility"]
df2.sort_values(by="Final Utility",ascending=True,inplace=True)
df2.head(20)
# Out:
#                                               Food Item  \
# 3515                       Celsius Sparkling Grape 12oz
# 3558             Campbell's Chicken Noodle Soup 10.75oz
# 3540           Hostess Crispy Mini Strawberry Crème 4oz
# 3634               OREO Frozen Dairy Dessert Bar 2.75oz
# 3337                            Musselman’s Apple Sauce
# 2384  KIND Snack Bar Peanut Butter Dark Chocolate - ...
# 3341                           White Chip Macadamia Nut
# 3616                         Cheeseburger Bite with Bun
# 456                                  Tortilla De Harina
# 3575                   Hershey’s Almond King Size 2.6oz
# 2353  Hershey's Snack Size Candy, Milk Chocolate Mil...
# 2399  Gerber Baby Food Banana Apple Pear - 4.0 oz x ...
# 2044                                   Coke® Zero Sugar
# 3520                          Gatorade Fruit Punch 64oz
# 2206                                             Orange
# 2050                           Honest Kids® Apple Juice
# 1938                                      Burrito Combo
# 1354                                  Whole Kernel Corn
# 3561               Cinnamon Toast Crunch Cereal Cup 2oz
# 3586               Reese's Peanut Butter Cup Mini 7.6oz
#
#       Explicit Dietry Utility  Ratings Utility  Price Utility Primary Flavour  \
# 3515                      4.0              0.2          0.259          Creamy
# 3558                      2.2              0.2          0.229          Fruity
# 3540                      2.0              0.2          0.309          Creamy
# 3634                      2.0              0.2          0.249          Fruity
# 3337                      3.4              0.1          0.200           Nutty
# 2384                      1.2              0.3          0.250          Creamy
# 3341                      3.0              0.1          0.100           Umami
# 3616                      3.2              0.2          0.199           Sweet
# 456                       0.2              0.3          0.310          Fruity
# 3575                      4.0              0.2          0.259          Herbal
# 2353                     -1.0              0.3          0.166          Herbal
# 2399                      4.0              0.3          0.240            Sour
# 2044                      3.0              0.3          0.245            Sour
# 3520                      3.2              0.2          0.349           Tangy
# 2206                      2.0              0.4          0.109           Spicy
# 2050                      3.2              0.3          0.215           Umami
# 1938                      2.0              0.6          0.000          Creamy
# 1354                      2.0              0.5          0.323          Fruity
# 3561                      3.2              0.2          0.239           Sweet
# 3586                      3.2              0.2          0.519          Creamy
#
#      Secondary Flavour  Time spent  Time Spent Utility  Implicit Utility 1  \
# 3515             Nutty         2.0                0.33                1.00
# 3558             Nutty         3.9                0.97                0.86
# 3540            Fruity         1.4                0.13                1.00
# 3634            Earthy         3.8                0.93                0.86
# 3337            Herbal         1.7                0.23                0.14
# 2384            Earthy         2.9                0.63                1.00
# 3341            Earthy         3.4                0.80                0.29
# 3616            Herbal         1.8                0.27                0.29
# 456               Sour         1.9                0.30                0.86
# 3575            Fruity         3.5                0.83                0.43
# 2353             Nutty         3.5                0.83                0.43
# 2399            Fruity         1.3                0.10                0.57
# 2044            Fruity         2.0                0.33                0.57
# 3520             Nutty         2.8                0.60                0.57
# 2206             Smoky         1.4                0.13                0.29
# 2050            Herbal         2.2                0.40                0.29
# 1938            Bitter         3.4                0.80                1.00
# 1354            Herbal         1.0                0.00                0.86
# 3561              Sour         3.2                0.73                0.29
# 3586            Earthy         3.4                0.80                1.00
#
#       Implicit Utility 2  Final Implicit utility  Final Utility
# 3515                 0.8                0.097386       0.556386
# 3558                 0.8                0.169216       0.598216
# 3540                 0.8                0.097386       0.606386
# 3634                 0.6                0.266602       0.715602
# 3337                 1.0                0.441240       0.741240
# 2384                 0.6                0.194772       0.744772
# 3341                 0.6                0.559052       0.759052
# 3616                 1.0                0.364279       0.763279
# 456                  0.8                0.169216       0.779216
# 3575                 0.8                0.389836       0.848836
# 2353                 0.8                0.389836       0.855836
# 2399                 0.8                0.318006       0.858006
# 2044                 0.8                0.318006       0.863006
# 3520                 0.8                0.318006       0.867006
# 2206                 1.0                0.364279       0.873279
# 2050                 1.0                0.364279       0.879279
# 1938                 0.4                0.292158       0.892158
# 1354                 1.0                0.071830       0.894830
# 3561                 0.8                0.461666       0.900666
# 3586                 0.6                0.194772       0.913772
